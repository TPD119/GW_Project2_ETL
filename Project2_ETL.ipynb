# %%
#Import dependencies
import path
import glob
import pandas as pd
import datetime
import pytz

# %%
#Loop thru CSV files for parking violations, and add to DataFrame
moving_list_ = []

moving_path = 'Moving_Violations_2018'
moving_allFiles = glob.glob(moving_path + "/*.csv")

for moving_file_ in moving_allFiles:
   df = pd.read_csv(moving_file_,index_col=None, header=0)
   moving_list_.append(df)

moving_df = pd.concat(moving_list_, axis = 0, ignore_index = True)

moving_df.head()
# Out:
# /Users/thomasdirienzo/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:11: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   # This is added back by InteractiveShellApp.init_path()
#   ACCIDENTINDICATOR  ADDRESS_ID  AGENCYID  FINEAMT  \
# 0                No     31943.0      25.0      100
# 1                No    814983.0      25.0      100
# 2                No    807819.0      25.0      100
# 3                No    805065.0      25.0      100
# 4                No    805065.0      25.0      100
#
#                          LOCATION  OBJECTID  PENALTY1  PENALTY2  ROW_  ROW_ID  \
# 0   3700 BLK SOUTHERN AVE SE SW/B  15293004         0       NaN   NaN     NaN
# 1  3RD ST TUNNEL NW N/B BY MA AVE  15293005         0       NaN   NaN     NaN
# 2         5200 BLK 14TH ST NW S/B  15293006         0       NaN   NaN     NaN
# 3          2200 BLOCK K ST NW E/B  15293007         0       NaN   NaN     NaN
# 4            2200 BLK K ST NW W/B  15293008         0       NaN   NaN     NaN
#
#    STREETSEGID           TICKETISSUEDATE TICKETTYPE  TOTALPAID VIOLATIONCODE  \
# 0       1435.0  2018-11-02T11:13:00.000Z     Moving      100.0          T119
# 1       6364.0  2018-11-12T07:15:00.000Z     Moving      100.0          T119
# 2       6705.0  2018-11-10T09:22:00.000Z     Moving      100.0          T119
# 3       4361.0  2018-11-16T10:10:00.000Z     Moving      100.0          T119
# 4       4361.0  2018-11-16T10:15:00.000Z     Moving      100.0          T119
#
#                           VIOLATIONDESC       XCOORD       YCOORD
# 0  SPEED 11-15 MPH OVER THE SPEED LIMIT  404133.5400  132428.0100
# 1  SPEED 11-15 MPH OVER THE SPEED LIMIT  398788.1561  136798.6603
# 2  SPEED 11-15 MPH OVER THE SPEED LIMIT  397102.6300  142844.3000
# 3  SPEED 11-15 MPH OVER THE SPEED LIMIT  395664.9200  137186.8900
# 4  SPEED 11-15 MPH OVER THE SPEED LIMIT  395664.9200  137186.8900

# %%
est = pytz.timezone('US/Eastern')
utc = pytz.utc
fmt = '%Y-%m-%d %H:%M:%S %Z%z'

moving_df['TICKETISSUEDATE'] = moving_df['TICKETISSUEDATE'].apply(lambda x:x.astimezone(est).strptime(fmt))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-3786bb6850a3> in <module>
#       3 fmt = '%Y-%m-%d %H:%M:%S %Z%z'
#       4
# ----> 5 moving_df['TICKETISSUEDATE'] = moving_df['TICKETISSUEDATE'].apply(lambda x:x.astimezone(est).strptime(fmt))
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    3589             else:
#    3590                 values = self.astype(object).values
# -> 3591                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3592
#    3593         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-36-3786bb6850a3> in <lambda>(x)
#       3 fmt = '%Y-%m-%d %H:%M:%S %Z%z'
#       4
# ----> 5 moving_df['TICKETISSUEDATE'] = moving_df['TICKETISSUEDATE'].apply(lambda x:x.astimezone(est).strptime(fmt))
#
# AttributeError: 'str' object has no attribute 'astimezone'

# %%
moving_df['TICKETISSUEDATE'] = pd.to_datetime(moving_df['TICKETISSUEDATE'])

#Set index to date, and add date column
moving_df = moving_df.set_index(pd.DatetimeIndex(moving_df['TICKETISSUEDATE']))

moving_df['Date'] = moving_df.index.date

moving_df.head()
# Out:
#                           ACCIDENTINDICATOR  ADDRESS_ID  AGENCYID  FINEAMT  \
# TICKETISSUEDATE
# 2018-11-02 11:13:00+00:00                No     31943.0      25.0      100
# 2018-11-12 07:15:00+00:00                No    814983.0      25.0      100
# 2018-11-10 09:22:00+00:00                No    807819.0      25.0      100
# 2018-11-16 10:10:00+00:00                No    805065.0      25.0      100
# 2018-11-16 10:15:00+00:00                No    805065.0      25.0      100
#
#                                                  LOCATION  OBJECTID  PENALTY1  \
# TICKETISSUEDATE
# 2018-11-02 11:13:00+00:00   3700 BLK SOUTHERN AVE SE SW/B  15293004         0
# 2018-11-12 07:15:00+00:00  3RD ST TUNNEL NW N/B BY MA AVE  15293005         0
# 2018-11-10 09:22:00+00:00         5200 BLK 14TH ST NW S/B  15293006         0
# 2018-11-16 10:10:00+00:00          2200 BLOCK K ST NW E/B  15293007         0
# 2018-11-16 10:15:00+00:00            2200 BLK K ST NW W/B  15293008         0
#
#                            PENALTY2  ROW_  ROW_ID  STREETSEGID  \
# TICKETISSUEDATE
# 2018-11-02 11:13:00+00:00       NaN   NaN     NaN       1435.0
# 2018-11-12 07:15:00+00:00       NaN   NaN     NaN       6364.0
# 2018-11-10 09:22:00+00:00       NaN   NaN     NaN       6705.0
# 2018-11-16 10:10:00+00:00       NaN   NaN     NaN       4361.0
# 2018-11-16 10:15:00+00:00       NaN   NaN     NaN       4361.0
#
#                                     TICKETISSUEDATE TICKETTYPE  TOTALPAID  \
# TICKETISSUEDATE
# 2018-11-02 11:13:00+00:00 2018-11-02 11:13:00+00:00     Moving      100.0
# 2018-11-12 07:15:00+00:00 2018-11-12 07:15:00+00:00     Moving      100.0
# 2018-11-10 09:22:00+00:00 2018-11-10 09:22:00+00:00     Moving      100.0
# 2018-11-16 10:10:00+00:00 2018-11-16 10:10:00+00:00     Moving      100.0
# 2018-11-16 10:15:00+00:00 2018-11-16 10:15:00+00:00     Moving      100.0
#
#                           VIOLATIONCODE                         VIOLATIONDESC  \
# TICKETISSUEDATE
# 2018-11-02 11:13:00+00:00          T119  SPEED 11-15 MPH OVER THE SPEED LIMIT
# 2018-11-12 07:15:00+00:00          T119  SPEED 11-15 MPH OVER THE SPEED LIMIT
# 2018-11-10 09:22:00+00:00          T119  SPEED 11-15 MPH OVER THE SPEED LIMIT
# 2018-11-16 10:10:00+00:00          T119  SPEED 11-15 MPH OVER THE SPEED LIMIT
# 2018-11-16 10:15:00+00:00          T119  SPEED 11-15 MPH OVER THE SPEED LIMIT
#
#                                 XCOORD       YCOORD        Date
# TICKETISSUEDATE
# 2018-11-02 11:13:00+00:00  404133.5400  132428.0100  2018-11-02
# 2018-11-12 07:15:00+00:00  398788.1561  136798.6603  2018-11-12
# 2018-11-10 09:22:00+00:00  397102.6300  142844.3000  2018-11-10
# 2018-11-16 10:10:00+00:00  395664.9200  137186.8900  2018-11-16
# 2018-11-16 10:15:00+00:00  395664.9200  137186.8900  2018-11-16

# %%
est = pytz.timezone('US/Eastern')
utc = pytz.utc
fmt = '%Y-%m-%d %H:%M:%S %Z%z'

moving_df['TICKETISSUEDATE'] = moving_df['TICKETISSUEDATE'].apply(lambda x:x.astimezone(est).strftime(fmt))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-2ee5ae31ccaf> in <module>
#       3 fmt = '%Y-%m-%d %H:%M:%S %Z%z'
#       4
# ----> 5 moving_df['TICKETISSUEDATE'] = moving_df['TICKETISSUEDATE'].apply(lambda x:x.astimezone(est).strftime(fmt))
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    3589             else:
#    3590                 values = self.astype(object).values
# -> 3591                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3592
#    3593         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-31-2ee5ae31ccaf> in <lambda>(x)
#       3 fmt = '%Y-%m-%d %H:%M:%S %Z%z'
#       4
# ----> 5 moving_df['TICKETISSUEDATE'] = moving_df['TICKETISSUEDATE'].apply(lambda x:x.astimezone(est).strftime(fmt))
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.Timestamp.tz_convert()
#
# TypeError: Cannot convert tz-naive Timestamp, use tz_localize to localize

# %%
moving_df.head()
# Out:
#                           ACCIDENTINDICATOR  ADDRESS_ID  AGENCYID  FINEAMT  \
# TICKETISSUEDATE
# 2018-11-02 11:13:00+00:00                No     31943.0      25.0      100
# 2018-11-12 07:15:00+00:00                No    814983.0      25.0      100
# 2018-11-10 09:22:00+00:00                No    807819.0      25.0      100
# 2018-11-16 10:10:00+00:00                No    805065.0      25.0      100
# 2018-11-16 10:15:00+00:00                No    805065.0      25.0      100
#
#                                                  LOCATION  OBJECTID  PENALTY1  \
# TICKETISSUEDATE
# 2018-11-02 11:13:00+00:00   3700 BLK SOUTHERN AVE SE SW/B  15293004         0
# 2018-11-12 07:15:00+00:00  3RD ST TUNNEL NW N/B BY MA AVE  15293005         0
# 2018-11-10 09:22:00+00:00         5200 BLK 14TH ST NW S/B  15293006         0
# 2018-11-16 10:10:00+00:00          2200 BLOCK K ST NW E/B  15293007         0
# 2018-11-16 10:15:00+00:00            2200 BLK K ST NW W/B  15293008         0
#
#                            PENALTY2  ROW_  ROW_ID  STREETSEGID  \
# TICKETISSUEDATE
# 2018-11-02 11:13:00+00:00       NaN   NaN     NaN       1435.0
# 2018-11-12 07:15:00+00:00       NaN   NaN     NaN       6364.0
# 2018-11-10 09:22:00+00:00       NaN   NaN     NaN       6705.0
# 2018-11-16 10:10:00+00:00       NaN   NaN     NaN       4361.0
# 2018-11-16 10:15:00+00:00       NaN   NaN     NaN       4361.0
#
#                           TICKETISSUEDATE TICKETTYPE  TOTALPAID VIOLATIONCODE  \
# TICKETISSUEDATE
# 2018-11-02 11:13:00+00:00      2018-11-02     Moving      100.0          T119
# 2018-11-12 07:15:00+00:00      2018-11-12     Moving      100.0          T119
# 2018-11-10 09:22:00+00:00      2018-11-10     Moving      100.0          T119
# 2018-11-16 10:10:00+00:00      2018-11-16     Moving      100.0          T119
# 2018-11-16 10:15:00+00:00      2018-11-16     Moving      100.0          T119
#
#                                                   VIOLATIONDESC       XCOORD  \
# TICKETISSUEDATE
# 2018-11-02 11:13:00+00:00  SPEED 11-15 MPH OVER THE SPEED LIMIT  404133.5400
# 2018-11-12 07:15:00+00:00  SPEED 11-15 MPH OVER THE SPEED LIMIT  398788.1561
# 2018-11-10 09:22:00+00:00  SPEED 11-15 MPH OVER THE SPEED LIMIT  397102.6300
# 2018-11-16 10:10:00+00:00  SPEED 11-15 MPH OVER THE SPEED LIMIT  395664.9200
# 2018-11-16 10:15:00+00:00  SPEED 11-15 MPH OVER THE SPEED LIMIT  395664.9200
#
#                                 YCOORD        Date
# TICKETISSUEDATE
# 2018-11-02 11:13:00+00:00  132428.0100  2018-11-02
# 2018-11-12 07:15:00+00:00  136798.6603  2018-11-12
# 2018-11-10 09:22:00+00:00  142844.3000  2018-11-10
# 2018-11-16 10:10:00+00:00  137186.8900  2018-11-16
# 2018-11-16 10:15:00+00:00  137186.8900  2018-11-16
